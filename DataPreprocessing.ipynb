# %% [markdown]
# <a href="https://colab.research.google.com/github/saran237/assignment/blob/main/DataPreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
#  **Load the dataset into a DataFrame**

# %%
df=pd.read_csv("/content/all_month.csv")
df
# Out:
#                            time   latitude   longitude     depth   mag  \
# 0      2025-07-21T06:08:16.330Z  35.948000 -117.666333    3.4200  0.26
# 1      2025-07-21T05:44:40.819Z  64.645900 -149.397100   19.7000  2.20
# 2      2025-07-21T05:43:42.750Z  18.258333  -66.338667   21.5000  1.95
# 3      2025-07-21T05:28:30.153Z  32.451000 -102.083000    4.9957  1.10
# 4      2025-07-21T05:22:41.240Z  60.170800 -151.877100   34.5000  1.10
# ...                         ...        ...         ...       ...   ...
# 10835  2025-06-21T06:48:24.357Z  51.845300 -173.437500   39.3000  2.00
# 10836  2025-06-21T06:46:28.670Z  33.321000 -116.297000   12.0200  0.86
# 10837  2025-06-21T06:44:12.010Z  40.746667 -112.050833    5.2600  0.94
# 10838  2025-06-21T06:41:56.395Z -32.830300  179.765900  226.8770  4.40
# 10839  2025-06-21T06:16:20.210Z  38.836166 -122.798668    2.3100  0.58
#
#       magType   nst    gap      dmin   rms  ...                   updated  \
# 0          ml  13.0   67.0  0.012950  0.08  ...  2025-07-21T06:11:37.459Z
# 1          ml   NaN    NaN       NaN  0.77  ...  2025-07-21T05:46:56.248Z
# 2          md   9.0  123.0  0.064340  0.13  ...  2025-07-21T06:09:57.640Z
# 3          ml  13.0  110.0  0.000000  0.50  ...  2025-07-21T06:00:14.519Z
# 4          ml   NaN    NaN       NaN  0.56  ...  2025-07-21T05:24:34.941Z
# ...       ...   ...    ...       ...   ...  ...                       ...
# 10835      ml   NaN    NaN       NaN  0.50  ...  2025-06-24T20:56:08.369Z
# 10836      ml  40.0   66.0  0.042590  0.19  ...  2025-06-22T14:24:05.213Z
# 10837      md  12.0   79.0  0.022740  0.12  ...  2025-06-23T15:39:01.960Z
# 10838      mb  18.0   98.0  4.085000  0.55  ...  2025-07-09T04:38:03.040Z
# 10839      md  11.0   68.0  0.006876  0.02  ...  2025-06-21T08:07:17.750Z
#
#                                      place        type horizontalError  \
# 0               22 km E of Little Lake, CA  earthquake            0.17
# 1      14 km WNW of Four Mile Road, Alaska  earthquake             NaN
# 2        6 km ENE of Orocovis, Puerto Rico  earthquake            0.46
# 3           33 km SSW of Los Ybanez, Texas  earthquake            0.00
# 4            17 km NW of Ninilchik, Alaska  earthquake             NaN
# ...                                    ...         ...             ...
# 10835             65 km SE of Atka, Alaska  earthquake             NaN
# 10836      10 km NE of Borrego Springs, CA  earthquake            0.24
# 10837               5 km NE of Magna, Utah  earthquake            0.36
# 10838        south of the Kermadec Islands  earthquake            8.95
# 10839                 7 km WNW of Cobb, CA  earthquake            0.38
#
#       depthError  magError  magNst     status  locationSource magSource
# 0       0.260000  0.100000     7.0  automatic              ci        ci
# 1       0.400000       NaN     NaN  automatic              ak        ak
# 2       0.880000  0.049740     4.0   reviewed              pr        pr
# 3       1.667254  0.200000     6.0  automatic              tx        tx
# 4       3.700000       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 10835   0.400000       NaN     NaN   reviewed              ak        ak
# 10836   0.520000  0.085000    16.0   reviewed              ci        ci
# 10837   0.760000  0.345847     4.0   reviewed              uu        uu
# 10838   7.447000  0.130000    17.0   reviewed              us        us
# 10839   0.940000  0.180000    11.0  automatic              nc        nc
#
# [10840 rows x 22 columns]

# %% [markdown]
# **Identify number of records and unique locations**

# %%
no_of_records=len(df)
no_of_records
# Out:
# 10840

# %%
split_place = df['place'].str.split(",",expand=True)
df[['place','split_place']]=split_place[[0,1]]
df
# Out:
#                            time   latitude   longitude     depth   mag  \
# 0      2025-07-21T06:08:16.330Z  35.948000 -117.666333    3.4200  0.26
# 1      2025-07-21T05:44:40.819Z  64.645900 -149.397100   19.7000  2.20
# 2      2025-07-21T05:43:42.750Z  18.258333  -66.338667   21.5000  1.95
# 3      2025-07-21T05:28:30.153Z  32.451000 -102.083000    4.9957  1.10
# 4      2025-07-21T05:22:41.240Z  60.170800 -151.877100   34.5000  1.10
# ...                         ...        ...         ...       ...   ...
# 10835  2025-06-21T06:48:24.357Z  51.845300 -173.437500   39.3000  2.00
# 10836  2025-06-21T06:46:28.670Z  33.321000 -116.297000   12.0200  0.86
# 10837  2025-06-21T06:44:12.010Z  40.746667 -112.050833    5.2600  0.94
# 10838  2025-06-21T06:41:56.395Z -32.830300  179.765900  226.8770  4.40
# 10839  2025-06-21T06:16:20.210Z  38.836166 -122.798668    2.3100  0.58
#
#       magType   nst    gap      dmin   rms  ...  \
# 0          ml  13.0   67.0  0.012950  0.08  ...
# 1          ml   NaN    NaN       NaN  0.77  ...
# 2          md   9.0  123.0  0.064340  0.13  ...
# 3          ml  13.0  110.0  0.000000  0.50  ...
# 4          ml   NaN    NaN       NaN  0.56  ...
# ...       ...   ...    ...       ...   ...  ...
# 10835      ml   NaN    NaN       NaN  0.50  ...
# 10836      ml  40.0   66.0  0.042590  0.19  ...
# 10837      md  12.0   79.0  0.022740  0.12  ...
# 10838      mb  18.0   98.0  4.085000  0.55  ...
# 10839      md  11.0   68.0  0.006876  0.02  ...
#
#                                place        type horizontalError depthError  \
# 0             22 km E of Little Lake  earthquake            0.17   0.260000
# 1        14 km WNW of Four Mile Road  earthquake             NaN   0.400000
# 2               6 km ENE of Orocovis  earthquake            0.46   0.880000
# 3            33 km SSW of Los Ybanez  earthquake            0.00   1.667254
# 4              17 km NW of Ninilchik  earthquake             NaN   3.700000
# ...                              ...         ...             ...        ...
# 10835               65 km SE of Atka  earthquake             NaN   0.400000
# 10836    10 km NE of Borrego Springs  earthquake            0.24   0.520000
# 10837               5 km NE of Magna  earthquake            0.36   0.760000
# 10838  south of the Kermadec Islands  earthquake            8.95   7.447000
# 10839               7 km WNW of Cobb  earthquake            0.38   0.940000
#
#        magError  magNst     status  locationSource  magSource   split_place
# 0      0.100000     7.0  automatic              ci         ci            CA
# 1           NaN     NaN  automatic              ak         ak        Alaska
# 2      0.049740     4.0   reviewed              pr         pr   Puerto Rico
# 3      0.200000     6.0  automatic              tx         tx         Texas
# 4           NaN     NaN  automatic              ak         ak        Alaska
# ...         ...     ...        ...             ...        ...           ...
# 10835       NaN     NaN   reviewed              ak         ak        Alaska
# 10836  0.085000    16.0   reviewed              ci         ci            CA
# 10837  0.345847     4.0   reviewed              uu         uu          Utah
# 10838  0.130000    17.0   reviewed              us         us          None
# 10839  0.180000    11.0  automatic              nc         nc            CA
#
# [10840 rows x 23 columns]

# %%
unique_location=df['split_place'].unique()
unique_location
print("Count of Unique Locations:",len(unique_location))
# Out:
# Count of Unique Locations: 97

# %% [markdown]
# ● Print top 5 rows and column names

# %%
print("Columns",df.columns.tolist())
print(df.head())
# Out:
# Columns ['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst', 'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'magNst', 'status', 'locationSource', 'magSource', 'split_place']
#                        time   latitude   longitude    depth   mag magType  \
# 0  2025-07-21T06:08:16.330Z  35.948000 -117.666333   3.4200  0.26      ml
# 1  2025-07-21T05:44:40.819Z  64.645900 -149.397100  19.7000  2.20      ml
# 2  2025-07-21T05:43:42.750Z  18.258333  -66.338667  21.5000  1.95      md
# 3  2025-07-21T05:28:30.153Z  32.451000 -102.083000   4.9957  1.10      ml
# 4  2025-07-21T05:22:41.240Z  60.170800 -151.877100  34.5000  1.10      ml
#
#     nst    gap     dmin   rms  ...                        place        type  \
# 0  13.0   67.0  0.01295  0.08  ...       22 km E of Little Lake  earthquake
# 1   NaN    NaN      NaN  0.77  ...  14 km WNW of Four Mile Road  earthquake
# 2   9.0  123.0  0.06434  0.13  ...         6 km ENE of Orocovis  earthquake
# 3  13.0  110.0  0.00000  0.50  ...      33 km SSW of Los Ybanez  earthquake
# 4   NaN    NaN      NaN  0.56  ...        17 km NW of Ninilchik  earthquake
#
#   horizontalError depthError magError  magNst     status  locationSource  \
# 0            0.17   0.260000  0.10000     7.0  automatic              ci
# 1             NaN   0.400000      NaN     NaN  automatic              ak
# 2            0.46   0.880000  0.04974     4.0   reviewed              pr
# 3            0.00   1.667254  0.20000     6.0  automatic              tx
# 4             NaN   3.700000      NaN     NaN  automatic              ak
#
#    magSource   split_place
# 0         ci            CA
# 1         ak        Alaska
# 2         pr   Puerto Rico
# 3         tx         Texas
# 4         ak        Alaska
#
# [5 rows x 23 columns]

# %% [markdown]
# ● Convert time to datetime

# %%
df['time'] = pd.to_datetime(df['time'])
df['time'].head()
# Out:
# 0   2025-07-21 06:08:16.330000+00:00
# 1   2025-07-21 05:44:40.819000+00:00
# 2   2025-07-21 05:43:42.750000+00:00
# 3   2025-07-21 05:28:30.153000+00:00
# 4   2025-07-21 05:22:41.240000+00:00
# Name: time, dtype: datetime64[ns, UTC]

# %% [markdown]
# ● Drop records with missing latitude, longitude, mag

# %%
df = df.dropna(subset=['latitude','longitude','mag'])
df
# Out:
#                                   time   latitude   longitude     depth   mag  \
# 0     2025-07-21 06:08:16.330000+00:00  35.948000 -117.666333    3.4200  0.26
# 1     2025-07-21 05:44:40.819000+00:00  64.645900 -149.397100   19.7000  2.20
# 2     2025-07-21 05:43:42.750000+00:00  18.258333  -66.338667   21.5000  1.95
# 3     2025-07-21 05:28:30.153000+00:00  32.451000 -102.083000    4.9957  1.10
# 4     2025-07-21 05:22:41.240000+00:00  60.170800 -151.877100   34.5000  1.10
# ...                                ...        ...         ...       ...   ...
# 10835 2025-06-21 06:48:24.357000+00:00  51.845300 -173.437500   39.3000  2.00
# 10836 2025-06-21 06:46:28.670000+00:00  33.321000 -116.297000   12.0200  0.86
# 10837 2025-06-21 06:44:12.010000+00:00  40.746667 -112.050833    5.2600  0.94
# 10838 2025-06-21 06:41:56.395000+00:00 -32.830300  179.765900  226.8770  4.40
# 10839 2025-06-21 06:16:20.210000+00:00  38.836166 -122.798668    2.3100  0.58
#
#       magType   nst    gap      dmin   rms  ...  \
# 0          ml  13.0   67.0  0.012950  0.08  ...
# 1          ml   NaN    NaN       NaN  0.77  ...
# 2          md   9.0  123.0  0.064340  0.13  ...
# 3          ml  13.0  110.0  0.000000  0.50  ...
# 4          ml   NaN    NaN       NaN  0.56  ...
# ...       ...   ...    ...       ...   ...  ...
# 10835      ml   NaN    NaN       NaN  0.50  ...
# 10836      ml  40.0   66.0  0.042590  0.19  ...
# 10837      md  12.0   79.0  0.022740  0.12  ...
# 10838      mb  18.0   98.0  4.085000  0.55  ...
# 10839      md  11.0   68.0  0.006876  0.02  ...
#
#                                place        type horizontalError depthError  \
# 0             22 km E of Little Lake  earthquake            0.17   0.260000
# 1        14 km WNW of Four Mile Road  earthquake             NaN   0.400000
# 2               6 km ENE of Orocovis  earthquake            0.46   0.880000
# 3            33 km SSW of Los Ybanez  earthquake            0.00   1.667254
# 4              17 km NW of Ninilchik  earthquake             NaN   3.700000
# ...                              ...         ...             ...        ...
# 10835               65 km SE of Atka  earthquake             NaN   0.400000
# 10836    10 km NE of Borrego Springs  earthquake            0.24   0.520000
# 10837               5 km NE of Magna  earthquake            0.36   0.760000
# 10838  south of the Kermadec Islands  earthquake            8.95   7.447000
# 10839               7 km WNW of Cobb  earthquake            0.38   0.940000
#
#        magError  magNst     status  locationSource  magSource   split_place
# 0      0.100000     7.0  automatic              ci         ci            CA
# 1           NaN     NaN  automatic              ak         ak        Alaska
# 2      0.049740     4.0   reviewed              pr         pr   Puerto Rico
# 3      0.200000     6.0  automatic              tx         tx         Texas
# 4           NaN     NaN  automatic              ak         ak        Alaska
# ...         ...     ...        ...             ...        ...           ...
# 10835       NaN     NaN   reviewed              ak         ak        Alaska
# 10836  0.085000    16.0   reviewed              ci         ci            CA
# 10837  0.345847     4.0   reviewed              uu         uu          Utah
# 10838  0.130000    17.0   reviewed              us         us          None
# 10839  0.180000    11.0  automatic              nc         nc            CA
#
# [10839 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# time                  0
# latitude              0
# longitude             0
# depth                 0
# mag                   0
# magType               0
# nst                1795
# gap                1796
# dmin               1884
# rms                   1
# net                   0
# id                    0
# updated               0
# place                 0
# type                  0
# horizontalError    2424
# depthError            4
# magError           1894
# magNst             1798
# status                0
# locationSource        0
# magSource             0
# split_place         172
# dtype: int64

# %% [markdown]
# ● Filter only earthquakes with magnitude >= 4.0

# %%
df_earthquake = df[df['mag'] >= 4.0]
df_earthquake
# Out:
#                                   time  latitude  longitude    depth  mag  \
# 11    2025-07-21 04:50:28.712000+00:00    0.0526   123.1965  161.784  4.8
# 17    2025-07-21 03:57:57.122000+00:00   52.5882   160.4530   10.000  4.2
# 25    2025-07-21 03:13:34.101000+00:00   52.2416   160.3604   10.000  4.3
# 28    2025-07-21 02:59:43.849000+00:00  -23.8341   -68.3654  121.348  4.3
# 29    2025-07-21 02:56:54.579000+00:00   52.6526   160.4971   10.000  4.2
# ...                                ...       ...        ...      ...  ...
# 10824 2025-06-21 07:32:52.177000+00:00   64.5456   -39.9838   10.000  4.2
# 10825 2025-06-21 07:28:00.268000+00:00   64.5288   -39.8376   10.000  4.5
# 10828 2025-06-21 07:23:59.651000+00:00  -23.8402  -179.9618  525.024  4.3
# 10829 2025-06-21 07:23:50.833000+00:00  -23.9369  -179.8111  529.302  4.1
# 10838 2025-06-21 06:41:56.395000+00:00  -32.8303   179.7659  226.877  4.4
#
#       magType    nst    gap    dmin   rms  ...  \
# 11         mb   70.0   54.0   2.147  1.01  ...
# 17         mb   22.0  195.0   1.178  0.79  ...
# 25         mb   32.0  152.0   1.304  0.60  ...
# 28         mb   28.0  103.0   0.895  0.94  ...
# 29         mb   28.0  120.0   1.180  1.16  ...
# ...       ...    ...    ...     ...   ...  ...
# 10824      mb   30.0   90.0   4.212  0.64  ...
# 10825      mb  105.0   54.0   4.239  0.62  ...
# 10828      mb   25.0  177.0   6.342  0.55  ...
# 10829      mb   24.0  244.0  14.516  0.59  ...
# 10838      mb   18.0   98.0   4.085  0.55  ...
#
#                                         place        type horizontalError  \
# 11                     55 km SSE of Gorontalo  earthquake            7.17
# 17     133 km ESE of Petropavlovsk-Kamchatsky  earthquake           10.40
# 25      148 km SE of Petropavlovsk-Kamchatsky  earthquake            7.54
# 28           103 km S of San Pedro de Atacama  earthquake            4.07
# 29     133 km ESE of Petropavlovsk-Kamchatsky  earthquake            5.94
# ...                                       ...         ...             ...
# 10824                   162 km SW of Tasiilaq  earthquake            8.27
# 10825                   159 km SW of Tasiilaq  earthquake            7.29
# 10828               south of the Fiji Islands  earthquake           20.27
# 10829               south of the Fiji Islands  earthquake           13.69
# 10838           south of the Kermadec Islands  earthquake            8.95
#
#       depthError magError  magNst    status  locationSource  magSource  \
# 11         7.130    0.047   143.0  reviewed              us         us
# 17         1.952    0.125    18.0  reviewed              us         us
# 25         1.921    0.114    23.0  reviewed              us         us
# 28         7.594    0.143    14.0  reviewed              us         us
# 29         1.796    0.121    20.0  reviewed              us         us
# ...          ...      ...     ...       ...             ...        ...
# 10824      1.919    0.124    18.0  reviewed              us         us
# 10825      1.837    0.057    91.0  reviewed              us         us
# 10828     17.708    0.119    20.0  reviewed              us         us
# 10829     14.241    0.127    20.0  reviewed              us         us
# 10838      7.447    0.130    17.0  reviewed              us         us
#
#       split_place
# 11      Indonesia
# 17         Russia
# 25         Russia
# 28          Chile
# 29         Russia
# ...           ...
# 10824   Greenland
# 10825   Greenland
# 10828        None
# 10829        None
# 10838        None
#
# [1036 rows x 23 columns]

# %% [markdown]
# ● Add a column day_of_week from time

# %%
df['column day_of_week']=df['time'].dt.day_name()
df
# Out:
# /tmp/ipython-input-12-577249182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['column day_of_week']=df['time'].dt.day_name()
#                                   time   latitude   longitude     depth   mag  \
# 0     2025-07-21 06:08:16.330000+00:00  35.948000 -117.666333    3.4200  0.26
# 1     2025-07-21 05:44:40.819000+00:00  64.645900 -149.397100   19.7000  2.20
# 2     2025-07-21 05:43:42.750000+00:00  18.258333  -66.338667   21.5000  1.95
# 3     2025-07-21 05:28:30.153000+00:00  32.451000 -102.083000    4.9957  1.10
# 4     2025-07-21 05:22:41.240000+00:00  60.170800 -151.877100   34.5000  1.10
# ...                                ...        ...         ...       ...   ...
# 10835 2025-06-21 06:48:24.357000+00:00  51.845300 -173.437500   39.3000  2.00
# 10836 2025-06-21 06:46:28.670000+00:00  33.321000 -116.297000   12.0200  0.86
# 10837 2025-06-21 06:44:12.010000+00:00  40.746667 -112.050833    5.2600  0.94
# 10838 2025-06-21 06:41:56.395000+00:00 -32.830300  179.765900  226.8770  4.40
# 10839 2025-06-21 06:16:20.210000+00:00  38.836166 -122.798668    2.3100  0.58
#
#       magType   nst    gap      dmin   rms  ...        type horizontalError  \
# 0          ml  13.0   67.0  0.012950  0.08  ...  earthquake            0.17
# 1          ml   NaN    NaN       NaN  0.77  ...  earthquake             NaN
# 2          md   9.0  123.0  0.064340  0.13  ...  earthquake            0.46
# 3          ml  13.0  110.0  0.000000  0.50  ...  earthquake            0.00
# 4          ml   NaN    NaN       NaN  0.56  ...  earthquake             NaN
# ...       ...   ...    ...       ...   ...  ...         ...             ...
# 10835      ml   NaN    NaN       NaN  0.50  ...  earthquake             NaN
# 10836      ml  40.0   66.0  0.042590  0.19  ...  earthquake            0.24
# 10837      md  12.0   79.0  0.022740  0.12  ...  earthquake            0.36
# 10838      mb  18.0   98.0  4.085000  0.55  ...  earthquake            8.95
# 10839      md  11.0   68.0  0.006876  0.02  ...  earthquake            0.38
#
#       depthError  magError magNst     status  locationSource  magSource  \
# 0       0.260000  0.100000    7.0  automatic              ci         ci
# 1       0.400000       NaN    NaN  automatic              ak         ak
# 2       0.880000  0.049740    4.0   reviewed              pr         pr
# 3       1.667254  0.200000    6.0  automatic              tx         tx
# 4       3.700000       NaN    NaN  automatic              ak         ak
# ...          ...       ...    ...        ...             ...        ...
# 10835   0.400000       NaN    NaN   reviewed              ak         ak
# 10836   0.520000  0.085000   16.0   reviewed              ci         ci
# 10837   0.760000  0.345847    4.0   reviewed              uu         uu
# 10838   7.447000  0.130000   17.0   reviewed              us         us
# 10839   0.940000  0.180000   11.0  automatic              nc         nc
#
#         split_place column day_of_week
# 0                CA             Monday
# 1            Alaska             Monday
# 2       Puerto Rico             Monday
# 3             Texas             Monday
# 4            Alaska             Monday
# ...             ...                ...
# 10835        Alaska           Saturday
# 10836            CA           Saturday
# 10837          Utah           Saturday
# 10838          None           Saturday
# 10839            CA           Saturday
#
# [10839 rows x 24 columns]

# %% [markdown]
# ● Create a column severity_level based on magnitude:
#
# ○ <4.0: "Low"
#
# ○ 4.0 - 6.0: "Moderate"
#
# ○ 6.0+: "High"

# %%
def severity_level(mag):
  if mag < 4.0:
    return 'Low'
  elif 4.0 <= mag <= 6.0:
    return 'Moderate'
  else:
    return 'High'

# %%
df['serenity_level'] = df['mag'].apply(severity_level)
df['serenity_level']
# Out:
# /tmp/ipython-input-14-1133588986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['serenity_level'] = df['mag'].apply(severity_level)
# 0             Low
# 1             Low
# 2             Low
# 3             Low
# 4             Low
#            ...
# 10835         Low
# 10836         Low
# 10837         Low
# 10838    Moderate
# 10839         Low
# Name: serenity_level, Length: 10839, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10839 entries, 0 to 10839
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time                10839 non-null  datetime64[ns, UTC]
#  1   latitude            10839 non-null  float64
#  2   longitude           10839 non-null  float64
#  3   depth               10839 non-null  float64
#  4   mag                 10839 non-null  float64
#  5   magType             10839 non-null  object
#  6   nst                 9044 non-null   float64
#  7   gap                 9043 non-null   float64
#  8   dmin                8955 non-null   float64
#  9   rms                 10838 non-null  float64
#  10  net                 10839 non-null  object
#  11  id                  10839 non-null  object
#  12  updated             10839 non-null  object
#  13  place               10839 non-null  object
#  14  type                10839 non-null  object
#  15  horizontalError     8415 non-null   float64
#  16  depthError          10835 non-null  float64
#  17  magError            8945 non-null   float64
#  18  magNst              9041 non-null   float64
#  19  status              10839 non-null  object
#  20  locationSource      10839 non-null  object
#  21  magSource           10839 non-null  object
#  22  split_place         10667 non-null  object
#  23  column day_of_week  10839 non-null  object
#  24  serenity_level      10839 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(12), object(12)
# memory usage: 2.2+ MB

# %% [markdown]
# Count number of earthquakes per place

# %%
place_counts = df['place'].value_counts()
print(place_counts.head(10))
# Out:
# place
# 22 km ENE of Ashford       563
# 23 km ENE of Ashford       329
# 7 km WNW of Cobb           113
# 8 km NNW of The Geysers    108
# 7 km NNW of The Geysers     80
# 12 km WNW of Calipatria     79
# 9 km WNW of Cobb            78
# 6 km WSW of Anza            76
# 7 km NW of The Geysers      74
# 8 km WNW of Cobb            71
# Name: count, dtype: int64

# %% [markdown]
# ● Compute average magnitude and max depth per day

# %%
daily_summary = df_earthquake.groupby(df_earthquake['time'].dt.date).agg(
    avg_magnitude=('mag', 'mean'),
    max_depth=('depth', 'max')
).reset_index()
print(daily_summary)
# Out:
#           time  avg_magnitude  max_depth
# 0   2025-06-21       4.580000    547.928
# 1   2025-06-22       4.424528    606.970
# 2   2025-06-23       4.463830    583.264
# 3   2025-06-24       4.517846    604.943
# 4   2025-06-25       4.575152    596.789
# 5   2025-06-26       4.534615    624.994
# 6   2025-06-27       4.552381    622.042
# 7   2025-06-28       4.542500    611.607
# 8   2025-06-29       4.503684    547.084
# 9   2025-06-30       4.495152    628.268
# 10  2025-07-01       4.465625    581.818
# 11  2025-07-02       4.660000    532.128
# 12  2025-07-03       4.617500    576.632
# 13  2025-07-04       4.563333    249.570
# 14  2025-07-05       4.525926    611.748
# 15  2025-07-06       4.716129    574.856
# 16  2025-07-07       4.521429    663.019
# 17  2025-07-08       4.672414    554.175
# 18  2025-07-09       4.631579    579.070
# 19  2025-07-10       4.616000    555.815
# 20  2025-07-11       4.560909    525.905
# 21  2025-07-12       4.604545    594.326
# 22  2025-07-13       4.637500    191.768
# 23  2025-07-14       4.768966    552.045
# 24  2025-07-15       4.780000    634.695
# 25  2025-07-16       4.665385    383.911
# 26  2025-07-17       4.715625    625.437
# 27  2025-07-18       4.678571    583.522
# 28  2025-07-19       4.716000    620.766
# 29  2025-07-20       4.840964    619.128
# 30  2025-07-21       4.355556    161.784

# %% [markdown]
# # Save:
# # ○ Cleaned dataset to cleaned_earthquakes.csv
# # ○ Summary data to earthquake_summary.csv

# %%
df_earthquake.to_csv("cleaned_earthquakes.csv", index=False)
daily_summary.to_csv("earthquake_summary.csv", index=False)

# %% [markdown]
# Store into SQLite table

# %%
import sqlite3

conn = sqlite3.connect("earthquakes.db")
df_earthquake.to_sql("earthquakes", conn, if_exists="replace", index=False)
daily_summary.to_sql("summary", conn, if_exists="replace", index=False)
conn.close()
